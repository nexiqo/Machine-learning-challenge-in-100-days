# %% [markdown]
# <a href="https://colab.research.google.com/github/nexiqo/Machine-learning-challenge-in-100-days/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class fraction(object):
    def __init__(self,num,den):
        self.num=num
        self.den=den


frack=fraction(1,2)
print(frack.den/frack.num)
print(frack.num)
print(frack.den)
# Out:
# 2.0
# 1
# 2

# %%
class fraction(object):
    def __init__(self,num,den):
        self.num=num
        self.den=den

    def __lt__(self,other):
        return (self.num / self.den) < (other.num / other.den)

    def __add__(self,other):
        # For addition: a/b + c/d = (ad + bc) / bd
        new_num = (self.num * other.den) + (other.num * self.den)
        new_den = self.den * other.den
        return fraction(new_num, new_den)

    def __mul__(self,other):
        # For multiplication: a/b * c/d = (ac) / (bd)
        new_num = self.num * other.num
        new_den = self.den * other.den
        return fraction(new_num, new_den)

    def __float__(self):
        return self.num / self.den

f1=fraction(1,2)
f2=f1.__mul__(f1) # Using __mul__ directly or f1 * f1 if operators are overloaded
# To test the __lt__ method, f2=f1.mul(f1) is 1/4. f1 is 1/2.
# So f1 < f2 should be False (1/2 < 1/4 is False)
# f1 > f2 should be True

# Let's verify with explicit fraction values for clearer test
f1_test = fraction(1,2)
f2_test = fraction(1,4) # Assuming f1.mul(f1) would result in 1/4 if f1 is 1/2

print(f1_test.__lt__(f2_test)) # This should print False (1/2 < 1/4 is False)

num =0
frac = fraction(0,1)
for _ in range(10):
  num +=0.1
  frac+=fraction(1,10)
print(f'num = {num}')
print(f'frac = {frac} = {float(frac)}')
# Out:
# False
# num = 0.9999999999999999
# frac = <__main__.fraction object at 0x796832cb1340> = 1.0

# %%
num =0
frac = fraction(0,1)
for _ in range(10):
  num +=0.1
  frac+=fraction(1,0)
  print(f'num = {num}'
  print(f'frac = {frac} = {float{(frac)}}'))
