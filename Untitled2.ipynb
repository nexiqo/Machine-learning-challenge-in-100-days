# %% [markdown]
# <a href="https://colab.research.google.com/github/nexiqo/Machine-learning-challenge-in-100-days/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def simple_make_payment(loan, payment_amt):
  payment_date = loan.get_start_date() + relativedelta(months=1)
  while loan.get_balance() > 0:
    balance = loan.get_balance()
    if balance < payment_amt:
      loan.make_payment(balance, payent_date)
    else:
      loan.make_payment(payment_amt, payment_date)
    payment_date += relativedelta(months=1)
