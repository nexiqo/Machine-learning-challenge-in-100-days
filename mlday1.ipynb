# %% [markdown]
# <a href="https://colab.research.google.com/github/nexiqo/Machine-learning-challenge-in-100-days/blob/main/mlday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Datasets in Pandas

# %% [markdown]
# ### Loading from a URL
#
# You can also load CSV files directly from a URL if they are publicly accessible.

# %%
import matplotlib.pyplot as plt
words=['hello','worlds','Iam','Computer']
freq=[5,6,1,8]
plt.bar(words,freq)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
c=['a','b','c','d','e']
a=np.array([1,2,3,4,5])
b=np.ones(5)
plt.ylim(0,7)
plt.bar(c,a+b)
plt.show()
print(a)
print(a+b)
# Out:
# [1 2 3 4 5]
# [2. 3. 4. 5. 6.]

# %%
import matplotlib.pyplot as plt
xpoints=[1,2,4,8]
ypoints=[3,6,1,15,8,9]#x goes in acending order
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
ypoints=[1,3,5,7,8]
plt.plot(ypoints,marker='o',ms='10')#ms = size of marker
plt.show()

# %%
import matplotlib.pyplot as plt
ypoints=[2,3,5,6,9]
plt.plot(ypoints,marker='o',mec='r',ms=10)#mec=border colour of marker

# %%
import matplotlib.pyplot as plt
ypoints=[1,1,2,2,3,3]
plt.plot(ypoints,marker='o',mfc='r',ms=10)

# %%
import matplotlib.pyplot as plt
ypoints=[2,4,7,9,6]
plt.plot(ypoints,color='r',linestyle='dashed')#color='r,g,b,c,m,y,k,w'  ,linestyle='solid,dashed,dotted,dot-dashed,points'

# %%
import matplotlib.pyplot as plt
height = [62,66,68,70,72,74,76]
male_weight=[123,131,139,148,157,168,181]
female_weight=[115,117,120,133,146,159,168]
plt.plot(height,male_weight)
plt.plot(height,female_weight)
plt.xlabel('height')
plt.ylabel('weight')
plt.title('weight vs height')
plt.legend(['male','female'])
plt.show()

# %%
# 1row, 2 column
import matplotlib.pyplot as plt
height = [62,66,68,70,72,74,76]
male_weight=[123,131,139,148,157,168,181]
female_weight=[115,117,120,133,146,159,168]
plt.subplot(1,2,1)
plt.ylim(100,200)
plt.grid()
plt.plot(height,male_weight,label='male')



plt.subplot(1,2,2)
plt.ylim(100,200)
plt.grid()
plt.plot(height,female_weight)

# %%
import matplotlib.pyplot as plt

xpoints = [1, 10, 5, 10, 20]
ypoints = [2, 20, 50, 1000, 200]

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#use random
import matplotlib.pyplot as plt
import numpy as np
import random
num_data_points = 25
days = np.random.rand(num_data_points)
students = np.random.rand(num_data_points)*120
size = np.random.rand(num_data_points) *100
plt.scatter(days,students,s = size)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
size=np.random.rand(30)*100
x=np.random.rand(30)
y=np.random.rand(30)

plt.scatter(x,y,s=size)

# %%
#width
import matplotlib.pyplot as plt
import numpy as np
import random
categories=np.array(["INTEREST","KNOWLEDGE","LEARNING","RATING"])
scores=np.array([5.6,4.3,6.1,6.3])
plt.bar(categories,scores,color='r',width=0.25)
plt.ylim(0,8)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["interest","knowledge","learning","rating"])
y=np.array([5.6,4.5,6.1,6.3])
plt.xlim(0,8)
plt.barh(x,y,color='green')
# Out:
# <BarContainer object of 4 artists>

# %%
from google.colab import drive
drive.mount('professor1.csv')
# Out:
# Mounted at professor1.csv

# %%
def plot_average_for_several_profs(file_list):
  profs = len(file_list)
  results_all=[]
  for file in file_list:
     raw_data, labels=read_in_data(file)
     results=raw_data.mean(axis=0)
     results_all.append(results)
  index=np.arrange(len(labels))
  bar_width=0.25
  for i in range (profs):
    plt.bar(index+i*bar_width,results_all[i],bar_width,label=labels[i])
    plt.ylim(0,8)
    plt.xticks(index+bar_width,labels)
    plt.legend()
    plt.show()
    plot_average_for_several_profs(['professor1.csv/'])

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-3,3,30)
y=x**2
plt.plot(x,y)
plt.show()
